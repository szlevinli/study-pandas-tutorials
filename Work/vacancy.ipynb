# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 分析空置情况
#
# ## 数据加载

# %%
vacancy = pd.read_excel("./data/vacancy.xlsx", parse_dates=["起始日期"])
vacancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   序号      719 non-null    int64
#  1   管理主体    719 non-null    object
#  2   项目名称    719 non-null    object
#  3   大厦名称    719 non-null    object
#  4   房号      719 non-null    object
#  5   用途      719 non-null    object
#  6   状态      708 non-null    object
#  7   面积      719 non-null    float64
#  8   使用率     708 non-null    float64
#  9   预计单价    719 non-null    float64
#  10  预计月租金   719 non-null    float64
#  11  起始日期    719 non-null    datetime64[ns]
#  12  空置天数    719 non-null    int64
#  13  空置月数    718 non-null    float64
#  14  空置时长    719 non-null    object
#  15  责任人     526 non-null    object
#  16  空置原因    150 non-null    object
#  17  解决措施    94 non-null     object
#  18  计划解决时间  279 non-null    float64
#  19  管理费     359 non-null    float64
#  20  备注      21 non-null     object
#  21  红黄灯     668 non-null    object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(12)
# memory usage: 123.7+ KB

# %% [markdown]
# ## 数据清洗

# %%
vacancy_simp = vacancy.iloc[:, [2, 3, 4, 7, 8, 9, 11, 15]].copy()
vacancy_simp
# Out:
#        项目名称   大厦名称                                    房号        面积    使用率  \
# 0      蛇口网谷   万融大厦                             A座303/305    866.39  0.700
# 1      蛇口网谷   万融大厦                              A401-402   1893.60  0.700
# 2      蛇口网谷   万融大厦  BG01/G02/G06/G07/G08/G09/G10/G11/G12    986.06  0.750
# 3      蛇口网谷   万融大厦                              A401-402   1893.60  0.700
# 4      蛇口网谷   万融大厦                                B座106A    211.90  0.750
# ..      ...    ...                                   ...       ...    ...
# 714  招商局芯云谷  6#孵化器                                   504    187.01  0.705
# 715  招商局芯云谷  6#孵化器                                   505    176.08  0.705
# 716  招商局芯云谷  6#孵化器                                   506    260.13  0.705
# 717  招商局芯云谷  6#孵化器                                   507    180.38  0.705
# 718  南昌东湖意库   整体项目                                  整体项目  12626.08    NaN
#
#       预计单价       起始日期   责任人
# 0    120.0 2019-04-01   曹泽宇
# 1    135.0 2021-04-01   曹泽宇
# 2    240.0 2020-09-01  商业小组
# 3    135.0 2021-04-01   张可言
# 4    135.0 2021-06-01   曹泽宇
# ..     ...        ...   ...
# 714   41.0 2019-11-26   NaN
# 715   41.0 2019-11-26   NaN
# 716   41.0 2019-11-26   NaN
# 717   41.0 2019-11-26   NaN
# 718   50.0 2021-05-31   NaN
#
# [719 rows x 8 columns]

# %% [markdown]
# 计算空置天数和空置月数. Pandas 专门提供了 Time deltas  来处理日期时间差. 两个日期时间相减会得到一个 dtype 是 `timedelta64[ns]`  对象来处理日期时间差的问题.

# %%
# 截止 2021 年 7 月 31 日 与空置起始日期间的差
vacant_timedelta = pd.to_datetime("2021-08-01") - vacancy_simp["起始日期"]
# 空置天数
vacant_days = (vacant_timedelta / np.timedelta64(1, "D")).astype("int")
# 空置月数
vacant_month = round(vacant_timedelta / np.timedelta64(1, "M"), 2)
vacancy_simp["vacant_days"] = vacant_days
vacancy_simp["vacant_month"] = vacant_month
vacancy_simp.head()
# Out:
#    项目名称  大厦名称                                    房号       面积   使用率   预计单价  \
# 0  蛇口网谷  万融大厦                             A座303/305   866.39  0.70  120.0
# 1  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 2  蛇口网谷  万融大厦  BG01/G02/G06/G07/G08/G09/G10/G11/G12   986.06  0.75  240.0
# 3  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 4  蛇口网谷  万融大厦                                B座106A   211.90  0.75  135.0
#
#         起始日期   责任人  vacant_days  vacant_month
# 0 2019-04-01   曹泽宇          853         28.03
# 1 2021-04-01   曹泽宇          122          4.01
# 2 2020-09-01  商业小组          334         10.97
# 3 2021-04-01   张可言          122          4.01
# 4 2021-06-01   曹泽宇           61          2.00

# %%
def rolling_window(window=2, data=[]):
    if len(data) <= window:
        return [data]
    else:
        return [data[:window]] + rolling_window(window, data[1:])
    
def bins_label(head='', tail='', template='{0} - {1}', bins=[]):
    return [head] + [template.format(i[0], i[1]) for i in rolling_window(data=bins)[1:-1]] + [tail]

# %% [markdown]
# 将"vacant_month"空置月份进行分箱操作, 创建"light_bins"列来表示红黄灯, 以及创建"vacancy_bins"列来表示空置时长

# %%
vacancy_month_bins = [0, 3, 6, 12, np.iinfo(np.int8).max]
ligth_labels = ['绿灯', '黄灯', '红灯', '红灯']
month_labels = bins_label(head='3个月内', tail='12个月以上', template='{0}到{1}个月', bins=vacancy_month_bins)

vacancy_simp['light_bins'] = pd.cut(vacancy_simp["vacant_month"], vacancy_month_bins, labels=ligth_labels, ordered=False)
vacancy_simp['vacancy_bins'] = pd.cut(vacancy_simp["vacant_month"], vacancy_month_bins, labels=month_labels)

vacancy_simp.head()
# Out:
#    项目名称  大厦名称                                    房号       面积   使用率   预计单价  \
# 0  蛇口网谷  万融大厦                             A座303/305   866.39  0.70  120.0
# 1  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 2  蛇口网谷  万融大厦  BG01/G02/G06/G07/G08/G09/G10/G11/G12   986.06  0.75  240.0
# 3  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 4  蛇口网谷  万融大厦                                B座106A   211.90  0.75  135.0
#
#         起始日期   责任人  vacant_days  vacant_month light_bins vacancy_bins
# 0 2019-04-01   曹泽宇          853         28.03         红灯       12个月以上
# 1 2021-04-01   曹泽宇          122          4.01         黄灯        3到6个月
# 2 2020-09-01  商业小组          334         10.97         红灯       6到12个月
# 3 2021-04-01   张可言          122          4.01         黄灯        3到6个月
# 4 2021-06-01   曹泽宇           61          2.00         绿灯         3个月内

# %% [markdown]
# 将面积进行分箱操作, 创建"area_bins"列

# %%
area_bins = [0, 100, 200, 300, 400, 500, 1000, 1500, 3000, np.iinfo(np.int16).max]
area_bins_labels = bins_label(head='100平以内', tail='3000平以上', template='{0}至{1}平', bins=area_bins)

vacancy_simp['area_bins'] = pd.cut(vacancy_simp['面积'], area_bins, labels=area_bins_labels)

vacancy_simp.head()
# Out:
#    项目名称  大厦名称                                    房号       面积   使用率   预计单价  \
# 0  蛇口网谷  万融大厦                             A座303/305   866.39  0.70  120.0
# 1  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 2  蛇口网谷  万融大厦  BG01/G02/G06/G07/G08/G09/G10/G11/G12   986.06  0.75  240.0
# 3  蛇口网谷  万融大厦                              A401-402  1893.60  0.70  135.0
# 4  蛇口网谷  万融大厦                                B座106A   211.90  0.75  135.0
#
#         起始日期   责任人  vacant_days  vacant_month light_bins vacancy_bins  \
# 0 2019-04-01   曹泽宇          853         28.03         红灯       12个月以上
# 1 2021-04-01   曹泽宇          122          4.01         黄灯        3到6个月
# 2 2020-09-01  商业小组          334         10.97         红灯       6到12个月
# 3 2021-04-01   张可言          122          4.01         黄灯        3到6个月
# 4 2021-06-01   曹泽宇           61          2.00         绿灯         3个月内
#
#     area_bins
# 0   500至1000平
# 1  1500至3000平
# 2   500至1000平
# 3  1500至3000平
# 4    200至300平

# %% [markdown]
# ## 数据分析
#
# ### 从面积的维度分析
#
# 分析面积与空置情况的关系, 首先分析红灯情况下, 哪些面积分段红灯比较多

# %%
# 按 面积分箱+灯分箱 分组
grouped_area_ligth = vacancy_simp.groupby(['area_bins', 'light_bins'])
# 分组统计记录数. 使用 agg 聚合函数后会返回一个 df
df_grouped_area_ligth_by_size = grouped_area_ligth.agg({'vacant_month': 'size'})
# 计算每组中各种灯的占比
# 难点: 对于多级分组如何求出下一级的分组在上一级分组中的占比
# 技巧: 使用 groupby() 函数的 level 参数, 再结合 apply() 函数来实现
df_grouped_area_ligth_by_size_percent = df_grouped_area_ligth_by_size.groupby(level=0).apply(lambda x: x / x.sum())
# rename cols
df_grouped_area_ligth_by_size_percent = df_grouped_area_ligth_by_size_percent.rename(columns={
    'vacant_month': 'percent'
})

df_grouped_area_ligth_by_size_percent
# Out:
#                         percent
# area_bins  light_bins
# 100平以内     红灯          0.743842
#            绿灯          0.088670
#            黄灯          0.167488
# 100至200平   红灯          0.343972
#            绿灯          0.634752
#            黄灯          0.021277
# 200至300平   红灯          0.701493
#            绿灯          0.164179
#            黄灯          0.134328
# 300至400平   红灯          0.678571
#            绿灯          0.267857
#            黄灯          0.053571
# 400至500平   红灯          0.870968
#            绿灯          0.064516
#            黄灯          0.064516
# 500至1000平  红灯          0.888889
#            绿灯          0.083333
#            黄灯          0.027778
# 1000至1500平 红灯          0.769231
#            绿灯          0.076923
#            黄灯          0.153846
# 1500至3000平 红灯          0.684211
#            绿灯          0.105263
#            黄灯          0.210526
# 3000平以上    红灯          0.750000
#            绿灯          0.250000
#            黄灯          0.000000

# %%
df_grouped_percent_red_light = df_grouped_area_ligth_by_size_percent.query('light_bins == "红灯"')
df_grouped_percent_red_light.sort_values(by='percent', ascending=False)
# Out:
#                         percent
# area_bins  light_bins
# 500至1000平  红灯          0.888889
# 400至500平   红灯          0.870968
# 1000至1500平 红灯          0.769231
# 3000平以上    红灯          0.750000
# 100平以内     红灯          0.743842
# 200至300平   红灯          0.701493
# 1500至3000平 红灯          0.684211
# 300至400平   红灯          0.678571
# 100至200平   红灯          0.343972

# %%
grouped_area_bins_light.head()
# Out:
#        项目名称   大厦名称                                    房号        面积    使用率  \
# 0      蛇口网谷   万融大厦                             A座303/305    866.39  0.700
# 1      蛇口网谷   万融大厦                              A401-402   1893.60  0.700
# 2      蛇口网谷   万融大厦  BG01/G02/G06/G07/G08/G09/G10/G11/G12    986.06  0.750
# 3      蛇口网谷   万融大厦                              A401-402   1893.60  0.700
# 4      蛇口网谷   万融大厦                                B座106A    211.90  0.750
# ..      ...    ...                                   ...       ...    ...
# 706  招商局芯云谷  6#孵化器                                   403     85.03  0.705
# 709  招商局芯云谷  6#孵化器                                   406    260.13  0.705
# 712  招商局芯云谷  6#孵化器                                   502    224.26  0.705
# 713  招商局芯云谷  6#孵化器                                   503     83.37  0.705
# 718  南昌东湖意库   整体项目                                  整体项目  12626.08    NaN
#
#       预计单价       起始日期  空置天数  空置月数   责任人  vacant_days  vacant_month light  \
# 0    120.0 2019-04-01   876  28.0   曹泽宇          887         29.15    红灯
# 1    135.0 2021-04-01   145   4.0   曹泽宇          156          5.13    黄灯
# 2    240.0 2020-09-01   357  11.0  商业小组          368         12.10    红灯
# 3    135.0 2021-04-01   124   4.0   张可言          156          5.13    黄灯
# 4    135.0 2021-06-01    84   2.0   曹泽宇           95          3.13    黄灯
# ..     ...        ...   ...   ...   ...          ...           ...   ...
# 706   40.0 2019-11-26   637  20.0   NaN          648         21.29    红灯
# 709   40.0 2019-11-26   637  20.0   NaN          648         21.29    红灯
# 712   41.0 2019-11-26   637  20.0   NaN          648         21.29    红灯
# 713   41.0 2019-11-26   637  20.0   NaN          648         21.29    红灯
# 718   50.0 2021-05-31    85   2.0   NaN           96          3.16    黄灯
#
#     vacancy   area_bins
# 0    12个月以上   500至1000平
# 1     3到6个月  1500至3000平
# 2    12个月以上   500至1000平
# 3     3到6个月  1500至3000平
# 4     3到6个月    200至300平
# ..      ...         ...
# 706  12个月以上      100平以内
# 709  12个月以上    200至300平
# 712  12个月以上    200至300平
# 713  12个月以上      100平以内
# 718   3到6个月     3000平以上
#
# [340 rows x 15 columns]

# %%
vacancy_simp.groupby(['项目名称','大厦名称'])['vacant_days'].nlargest()
# Out:
# 项目名称  大厦名称
# W6仓   前海易港中心  87     197
#               88     197
#               89     197
#               90     197
#               91     197
#                     ...
# 高铁网谷  高铁大厦    226    639
#               227    639
#               228    639
#               229    639
#               261    273
# Name: vacant_days, Length: 222, dtype: int64

# %%
vacancy_simp.sort_values(by='vacant_days', ascending=False).groupby(['项目名称'], as_index=False).first()
# Out:
#       项目名称     大厦名称            房号            面积       使用率        预计单价  \
# 0      W6仓   前海易港中心          302库   2139.210000  1.000000   38.000000
# 1    W6辅助楼   前海易港中心      2、3、4、8层   4946.820000  0.700000   48.000000
# 2     东湖网谷      7号楼           206    158.260000  0.711400   58.000000
# 3     仙东网谷     仙东网谷      3-8楼部分房源   2141.660000  0.630000   36.000000
# 4    光明科技园       A3         04C-5    143.970000  0.750000   60.000000
# 5   南昌东湖意库     整体项目          整体项目  12626.080000       NaN   50.000000
# 6     南海意库       1栋          103B    244.090000  0.760000  240.000000
# 7     庐州意库     庐州意库       6#401-1    358.580000  0.952117   70.000000
# 8   招商局芯云谷   3#人才公寓           613     80.560000  0.750200   24.826216
# 9   文化艺术中心        /           212    399.480000  0.586000  124.000000
# 10   番禺科技园    创启3号楼       2-3#401    540.250240  0.700000   29.000000
# 11    福永意库      7号楼          L167    126.630000  0.930000   96.000000
# 12    福海意库  5栋（A3栋）         A3栋岗亭     11.910000  1.000000   60.500000
# 13    紫金智谷      3号楼           401    205.170000  0.700000   59.310000
# 14  蕲春产促中心   蕲春产促中心  3-04-B05-B06    456.000000  0.860000   24.150000
# 15    蛇口网谷     万海大厦        C座704C    198.740000  0.780000  118.000000
# 16  重庆金山意库       2栋           209    139.260000  0.644300    5.250000
# 17    青岛网谷   基金谷1#楼           403    301.020000  0.680000   19.500000
# 18    高新网谷      1号楼          1404    171.652384  0.700400   39.000000
# 19    高铁网谷     高铁大厦          A106    328.000000  0.600000  135.000000
#
#          起始日期      责任人  vacant_days  vacant_month light_bins vacancy_bins  \
# 0  2021-01-16      张志宇          197          6.47         红灯       6到12个月
# 1  2018-07-01      张志宇         1127         37.03         红灯       12个月以上
# 2  2020-11-01       王琼          273          8.97         红灯       6到12个月
# 3  2020-01-01       方亮          578         18.99         红灯       12个月以上
# 4  2020-01-01      黄丁可          578         18.99         红灯       12个月以上
# 5  2021-05-31      NaN           62          2.04         绿灯         3个月内
# 6  2020-12-24     商业小组          220          7.23         红灯       6到12个月
# 7  2021-07-01      魏从林           31          1.02         绿灯         3个月内
# 8  2019-11-26       全员          614         20.17         红灯       12个月以上
# 9  2019-06-01       林巧          792         26.02         红灯       12个月以上
# 10 2014-02-01      涂善安         2738         89.96         红灯       12个月以上
# 11 2019-10-29       喻南          642         21.09         红灯       12个月以上
# 12 2020-09-30       喻南          305         10.02         红灯       6到12个月
# 13 2020-09-01       丁敬          334         10.97         红灯       6到12个月
# 14 2018-05-01  杨子文（黄景）         1188         39.03         红灯       12个月以上
# 15 2019-02-01      杨清清          912         29.96         红灯       12个月以上
# 16 2017-01-01      范志刚         1673         54.97         红灯       12个月以上
# 17 2019-12-31      王玉文          579         19.02         红灯       12个月以上
# 18 2021-06-01   陈龙、肖汪凯           61          2.00         绿灯         3个月内
# 19 2019-11-01      潘丽丽          639         20.99         红灯       12个月以上
#
#      area_bins
# 0   1500至3000平
# 1      3000平以上
# 2     100至200平
# 3   1500至3000平
# 4     100至200平
# 5      3000平以上
# 6     200至300平
# 7     300至400平
# 8       100平以内
# 9     300至400平
# 10   500至1000平
# 11    100至200平
# 12      100平以内
# 13    200至300平
# 14    400至500平
# 15    100至200平
# 16    100至200平
# 17    300至400平
# 18    100至200平
# 19    300至400平

# %%
import pandas._testing as tm

frame = tm.makeTimeDataFrame(3)
frame
# Out:
#                    A         B         C         D
# 2000-01-03  0.397228  0.021911  0.481974 -0.218343
# 2000-01-04 -0.122126 -0.051248 -1.237669 -3.057918
# 2000-01-05  0.573423  1.296903 -0.126138 -0.409968

# %%
frame.shape
# Out:
# (3, 4)

# %%
frame.to_numpy().ravel('F')
# Out:
# array([ 0.3972278 , -0.12212637,  0.57342319,  0.02191096, -0.05124767,
#         1.29690319,  0.48197359, -1.23766935, -0.12613828, -0.2183427 ,
#        -3.05791823, -0.40996776])

# %%
np.asarray(frame.columns).repeat(3)
# Out:
# array(['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C', 'D', 'D', 'D'],
#       dtype=object)

# %%
np.tile(np.asarray(frame.index), 4)
# Out:
# array(['2000-01-03T00:00:00.000000000', '2000-01-04T00:00:00.000000000',
#        '2000-01-05T00:00:00.000000000', '2000-01-03T00:00:00.000000000',
#        '2000-01-04T00:00:00.000000000', '2000-01-05T00:00:00.000000000',
#        '2000-01-03T00:00:00.000000000', '2000-01-04T00:00:00.000000000',
#        '2000-01-05T00:00:00.000000000', '2000-01-03T00:00:00.000000000',
#        '2000-01-04T00:00:00.000000000', '2000-01-05T00:00:00.000000000'],
#       dtype='datetime64[ns]')
